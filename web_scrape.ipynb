# %%
import requests
from bs4 import BeautifulSoup

# Define the URL you want to scrape

temp = 0
city = []
names = []
prices = []
ratings = []
review_titles = []
review_counts = []
dist = []
breakfast = []
room_type = []
beds = []
sustainable = []
cancellation = []
prepayment = []
Staff = []
Facilities = []
Cleanliness = []
Comfort = []
Value_for_money = []
Location = []
Wifi = []

# mew = []


headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}

hotel_info = {}
hotel_info["Free WiFi"] = -1
hotel_info["Staff"] = -1
def inside_url(url):

    hotel_info["Free WiFi"] = -1
    hotel_info["Staff"] = -1
    hotel_info["Facilities"] = -1
    hotel_info["Cleanliness"] = -1
    hotel_info["Comfort"] = -1
    hotel_info['Value for money'] = -1
    hotel_info["Location"] = -1
    # Send an HTTP GET request with the headers
    response = requests.get(url, headers=headers)

    # Initialize lists to store hotel information

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, "html.parser")

        soup = BeautifulSoup(response.text, "html.parser")
        temp1 = soup.find("div", class_="bui-spacer--larger")
        if temp1 is None:
          # hotelname = soup.find("h2", class_="d2fee87262 pp-header__title")
          return -1
        names = temp1.find_all("span", class_="be887614c2")

        text_list = [name.get_text(strip=True) for name in names]

        values = temp1.find_all("div", class_="ccb65902b2 efcd70b4c4")
        rating_list = [value.get_text(strip=True) for value in values]

        # print(len(text_list), len(rating_list))

        for i in range(len(rating_list)):
          hotel_info[text_list[i]] = (

              rating_list[i]
              if rating_list[i]
              else "Not Found"
              )

def hotels(url, city_name):
    # Set a user-agent to mimic a web browser


    # Send an HTTP GET request with the headers
    response = requests.get(url, headers=headers)

    # Initialize lists to store hotel information

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, "html.parser")

        # Extract hotel listings
        hotel_listings = soup.find_all("div", class_="c1edfbabcb")
        first_iteration = True
        # Loop through the hotel listings
        for hotel in hotel_listings:
            if first_iteration:
            # Set the flag to False for subsequent iterations
              first_iteration = False
              continue
            # Initialize a dictionary to store hotel information


            new = hotel.find("a", class_="a83ed08757 c21c56c305 a4c1805887 d691166b09 ab98298258 deab83296e c082d89982 ff33faec5f")
            new = new.get('href')
            new = new.split('&')[0]

            # continue if no block
            # print(new)
            # break
            ans = inside_url(new)
            if ans == -1:
              continue


            hotel_name = hotel.find("div", class_="f6431b446c a15b38c233")
            price_elem = hotel.find("span", class_="f6431b446c fbfd7c1165 e84eb96b1f")

            rating_elem = hotel.find("div", class_="a3b8729ab1 d86cee9b25")
            review_title_elem = hotel.find(
                "div", class_="a3b8729ab1 e6208ee469 cb2cbb3ccb"
            )
            # dist_from_center = hotel.find("span", class_="f419a93f12")
            review_count_elem = hotel.find(
                "div", class_="abf093bdfe f45d8e4c32 d935416c47"
            )
            distance_elem = hotel.find("span", {"data-testid": "distance"})


            room_type_elem = hotel.find(
                "h4", class_="abf093bdfe e8f7c070a7"
            )
            beds_elem = hotel.find(
                "div", class_="fc367255e6"
            )
            sus_elem = hotel.find(
                "span", class_="abf093bdfe d068504c75 f68ecd98ea"
            )

            cancel_elem = hotel.find(
                "div", class_="abf093bdfe d068504c75"
            )

            prepayment_elem = hotel.find(
                "div", class_="abf093bdfe d068504c75"
            )
            data_list = []




            # Check if elements are found before accessing their attributes
            hotel_info["Name"] = (
                hotel_name.get_text(strip=True) if hotel_name else "Not Found"
            )
            hotel_info["Price"] = (
                price_elem.get_text(strip=True) if price_elem else "Not Found"
            )
            hotel_info["Rating"] = (
                rating_elem.get_text(strip=True) if rating_elem else "Not Found"
            )
            hotel_info["Review Title"] = (
                review_title_elem.get_text(strip=True)
                if review_title_elem
                else "Not Found"
            )
            hotel_info["Review Count"] = (
                review_count_elem.get_text(strip=True)
                if review_count_elem
                else "Not Found"
            )
            hotel_info["Distance"] = (
                distance_elem.get_text(strip=True)
                if distance_elem
                else "Not Found"
            )

            hotel_info["new"] = (
                new

            )

            hotel_info["Room type"] = (
                room_type_elem.get_text(strip=True)
                if room_type_elem
                else "Not Found"
            )
            hotel_info["Beds"] = (
                beds_elem.get_text(strip=True)
                if beds_elem
                else "Not Found"
            )

            hotel_info["Sustainable"] = (
                sus_elem.get_text(strip=True)
                if sus_elem
                else "Not Found"
            )

            hotel_info["Cancellation"] = (
                cancel_elem.get_text(strip=True)
                if cancel_elem
                else "No Free Cancellation"
            )

            # Append hotel information to the lists
            # mew.append(new)
            city.append(city_name)
            names.append(hotel_info["Name"])
            prices.append(hotel_info["Price"])
            ratings.append(hotel_info["Rating"])
            review_titles.append(hotel_info["Review Title"])
            review_counts.append(hotel_info["Review Count"])
            dist.append(hotel_info["Distance"])
            # breakfast.append(hotel_info["Breakfast"])
            room_type.append(hotel_info["Room type"])
            beds.append(hotel_info["Beds"])
            sustainable.append(hotel_info["Sustainable"])
            cancellation.append(hotel_info["Cancellation"])
            Staff.append(hotel_info["Staff"])
            Facilities.append(hotel_info["Facilities"])
            Cleanliness.append(hotel_info["Cleanliness"])
            Comfort.append(hotel_info["Comfort"])
            Value_for_money.append(hotel_info["Value for money"])
            Location.append(hotel_info["Location"])
            Wifi.append(hotel_info["Free WiFi"])


    else:
        print("Failed to retrieve the page. Status code:", response.status_code)

# For Lahore
# 0 to 400
for i in range(0, 400, 25):
    temp1 = str(i)
    url = (
            "https://www.booking.com/searchresults.en-gb.html?ss=Lahore&ssne=Lahore&ssne_untouched=Lahore&label=gog235jc-1DCAEoggI46AdIM1gDaLUBiAEBmAEJuAEZyAEP2AED6AEBiAIBqAIDuALm-tKqBsACAdICJGU0ZWY0NTA1LTE2ZWItNGI1Ny05ZTZiLTU2YjVkOTAxOGVhNNgCBOACAQ&sid=0fa4ebc5e46a2e63ac26b293c9326f9b&aid=397594&lang=en-gb&sb=1&src_elem=sb&src=index&dest_id=-2767043&dest_type=city&checkin=2023-11-17&checkout=2023-11-18&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset="
        + temp1
    )
    hotels(url, "Lahore")
print("Lahore done")


# # For Islamabad
for i in range(0, 400, 25):
  temp1 = str(i)
  url = (
          "https://www.booking.com/searchresults.en-gb.html?ss=Islamabad%2C+Pakistan&ssne=Lahore&ssne_untouched=Lahore&label=gog235jc-1DCAEoggI46AdIM1gDaLUBiAEBmAEJuAEZyAEP2AED6AEBiAIBqAIDuALm-tKqBsACAdICJGU0ZWY0NTA1LTE2ZWItNGI1Ny05ZTZiLTU2YjVkOTAxOGVhNNgCBOACAQ&sid=0fa4ebc5e46a2e63ac26b293c9326f9b&aid=397594&lang=en-gb&sb=1&src_elem=sb&src=index&dest_id=-2762812&dest_type=city&checkin=2023-11-17&checkout=2023-11-18&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset="
      + temp1
  )
  hotels(url, "Islamabad")

# # For khi
for i in range(0, 400, 25):
  temp1 = str(i)
  url = (
          "https://www.booking.com/searchresults.en-gb.html?ss=Karachi%2C+Pakistan&ssne=Lahore&ssne_untouched=Lahore&label=gog235jc-1DCAEoggI46AdIM1gDaLUBiAEBmAEJuAEZyAEP2AED6AEBiAIBqAIDuALm-tKqBsACAdICJGU0ZWY0NTA1LTE2ZWItNGI1Ny05ZTZiLTU2YjVkOTAxOGVhNNgCBOACAQ&sid=0fa4ebc5e46a2e63ac26b293c9326f9b&aid=397594&lang=en-gb&sb=1&src_elem=sb&src=index&dest_id=-2764584&dest_type=city&checkin=2023-11-17&checkout=2023-11-18&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset="
      + temp1
  )
  hotels(url, "Karachi")

# # For Murree
for i in range(0, 200, 25):
  temp1 = str(i)
  url = (
          "https://www.booking.com/searchresults.en-gb.html?ss=Murree%2C+Pakistan&ssne=Lahore&ssne_untouched=Lahore&label=gog235jc-1DCAEoggI46AdIM1gDaLUBiAEBmAEJuAEZyAEP2AED6AEBiAIBqAIDuALm-tKqBsACAdICJGU0ZWY0NTA1LTE2ZWItNGI1Ny05ZTZiLTU2YjVkOTAxOGVhNNgCBOACAQ&sid=0fa4ebc5e46a2e63ac26b293c9326f9b&aid=397594&lang=en-gb&sb=1&src_elem=sb&src=index&dest_id=-2769851&dest_type=city&checkin=2023-11-17&checkout=2023-11-18&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset="
      + temp1
  )
  hotels(url, "Murree")
# # +100

for i in range(0, 150, 25):
  temp1 = str(i)
  url = (
            "https://www.booking.com/searchresults.en-gb.html?ss=Multan%2C+Punjab+Region%2C+Pakistan&ssne=Lahore&ssne_untouched=Lahore&label=gog235jc-1DCAEoggI46AdIM1gDaLUBiAEBmAEJuAEZyAEP2AED6AEBiAIBqAIDuALm-tKqBsACAdICJGU0ZWY0NTA1LTE2ZWItNGI1Ny05ZTZiLTU2YjVkOTAxOGVhNNgCBOACAQ&sid=0fa4ebc5e46a2e63ac26b293c9326f9b&aid=397594&lang=en-gb&sb=1&src_elem=sb&src=index&dest_id=-2769709&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=349259b3096d00f7&ac_meta=GhAzNDkyNTliMzA5NmQwMGY3IAAoATICZW46A211bEAASgBQAA%3D%3D&checkin=2023-11-17&checkout=2023-11-18&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset="
      + temp1
  )
  hotels(url, "Multan")
# # +50

for i in range(0, 150, 25):
  temp1 = str(i)
  url = (
            "https://www.booking.com/searchresults.en-gb.html?ss=Rawalpindi%2C+Islamabad+Capital+Territory%2C+Pakistan&ssne=Lahore&ssne_untouched=Lahore&label=gog235jc-1DCAEoggI46AdIM1gDaLUBiAEBmAEJuAEZyAEP2AED6AEBiAIBqAIDuALm-tKqBsACAdICJGU0ZWY0NTA1LTE2ZWItNGI1Ny05ZTZiLTU2YjVkOTAxOGVhNNgCBOACAQ&sid=0fa4ebc5e46a2e63ac26b293c9326f9b&aid=397594&lang=en-gb&sb=1&src_elem=sb&src=index&dest_id=-2772585&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=349259b3096d00f7&ac_meta=GhAzNDkyNTliMzA5NmQwMGY3IAAoATICZW46BXJhd2FsQABKAFAA&checkin=2023-11-17&checkout=2023-11-18&group_adults=2&no_rooms=1&group_children=0&sb_travel_purpose=leisure&offset="
      + temp1
  )
  hotels(url, "Rawalpindi")
  # +120
# Out:
# Lahore done

# %% [markdown]
# URLS

# %%
lahore_url = "https://www.booking.com/searchresults.en-gb.html?label=en-pk-booking-desktop-HdF8vFGivk9B*m3Lg2C_aAS652735321099%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-98299850%3Alp9076955%3Ali%3Adec%3Adm&aid=2336991&ss=Lahore&ssne=Lahore&ssne_untouched=Lahore&efdco=1&lang=en-gb&src=searchresults&dest_id=-2767043&dest_type=city&checkin=2023-11-07&checkout=2023-11-08&ltfd=5%3A1%3A10-2023%3A%3A&group_adults=2&no_rooms=1&group_children=0&offset="
isl_url = "https://www.booking.com/searchresults.en-gb.html?ss=Islamabad%2C+Pakistan&ssne=Lahore&ssne_untouched=Lahore&label=en-pk-booking-desktop-HdF8vFGivk9B*m3Lg2C_aAS652735321099%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-98299850%3Alp9076955%3Ali%3Adec%3Adm&aid=2336991&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2762812&dest_type=city&checkin=2023-11-07&checkout=2023-11-08&ltfd=5%3A1%3A10-2023%3A%3A&group_adults=2&no_rooms=1&group_children=0&offset="
khi_url = "https://www.booking.com/searchresults.en-gb.html?ss=Karachi%2C+Pakistan&ssne=Islamabad&ssne_untouched=Islamabad&label=en-pk-booking-desktop-HdF8vFGivk9B*m3Lg2C_aAS652735321099%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-98299850%3Alp9076955%3Ali%3Adec%3Adm&aid=2336991&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2764584&dest_type=city&checkin=2023-11-07&checkout=2023-11-08&ltfd=5%3A1%3A10-2023%3A%3A&group_adults=2&no_rooms=1&group_children=0&offset="
murree_url = "https://www.booking.com/searchresults.en-gb.html?ss=Murree%2C+Pakistan&ssne=Karachi&ssne_untouched=Karachi&label=en-pk-booking-desktop-HdF8vFGivk9B*m3Lg2C_aAS652735321099%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-98299850%3Alp9076955%3Ali%3Adec%3Adm&aid=2336991&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2769851&dest_type=city&checkin=2023-11-07&checkout=2023-11-08&ltfd=5%3A1%3A10-2023%3A%3A&group_adults=2&no_rooms=1&group_children=0&offset="
multan_url = "https://www.booking.com/searchresults.en-gb.html?ss=Multan%2C+Punjab+Region%2C+Pakistan&ssne=Murree&ssne_untouched=Murree&label=en-pk-booking-desktop-HdF8vFGivk9B*m3Lg2C_aAS652735321099%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-98299850%3Alp9076955%3Ali%3Adec%3Adm&aid=2336991&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2769709&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=13375eb46feb0018&ac_meta=GhAxMzM3NWViNDZmZWIwMDE4IAAoATICZW46A011bEAASgBQAA%3D%3D&checkin=2023-11-07&checkout=2023-11-08&ltfd=5%3A1%3A10-2023%3A%3A&group_adults=2&no_rooms=1&group_children=0&offset="
rawalpindi_url = "https://www.booking.com/searchresults.en-gb.html?ss=Rawalpindi%2C+Pakistan&ssne=Multan&ssne_untouched=Multan&label=en-pk-booking-desktop-HdF8vFGivk9B*m3Lg2C_aAS652735321099%3Apl%3Ata%3Ap1%3Ap2%3Aac%3Aap%3Aneg%3Afi%3Atikwd-98299850%3Alp9076955%3Ali%3Adec%3Adm&aid=2336991&lang=en-gb&sb=1&src_elem=sb&src=searchresults&dest_id=-2772585&dest_type=city&checkin=2023-11-07&checkout=2023-11-08&ltfd=5%3A1%3A10-2023%3A%3A&group_adults=2&no_rooms=1&group_children=0&offset="

# %%
import csv

with open("hotel5_data.txt", "w", newline='') as file:
    writer = csv.writer(file, quoting=csv.QUOTE_MINIMAL, delimiter=',')

    # Write the header row
    writer.writerow([
        "Name", "Price", "Rating", "Review Title", "Review Count",
        "Distance", "Beds", "Room Type", "Sustainable", "Cancellation", "City,","Staff",
        "Facilities", "Cleanliness", "Comfort", "Value for money", "Location", "Free WiFi"
    ])

    for i in range(len(names)):
        # Prepare the data as a list
        data = [
            names[i], prices[i], ratings[i], review_titles[i], review_counts[i],
            dist[i], beds[i], room_type[i], sustainable[i], cancellation[i], city[i],
            Staff[i], Facilities[i], Cleanliness[i], Comfort[i], Value_for_money[i], Location[i], Wifi[i]
        ]
        writer.writerow(data)

file.close()

# %% [markdown]
# karachi

# %%
import csv
import pandas as pd

# Define the file path
file_path = "./hotel5_data.txt"

df = pd.read_csv(file_path)

df.head()
# Out:
#                            Name  Price  Rating Review Title   Review Count  \
# 0             Luxus Grand Hotel  US$62     9.2       Superb  1,685 reviews
# 1        Park Lane Hotel Lahore  US$56     8.2    Very good  2,185 reviews
# 2          Falettis Express DHA  US$33     7.4         Good    496 reviews
# 3  City View Hotel & Restaurant  US$17     7.8         Good    547 reviews
# 4          Avari Xpress Gulberg  US$55     8.1    Very good  2,999 reviews
#
#                 Distance                      Beds             Room Type  \
# 0  0.4 miles from centre              1 double bed    Deluxe Double Room
# 1  4.3 miles from centre        Multiple bed types      Deluxe King Room
# 2  6.2 miles from centre  1 extra-large double bed  Standard Double Room
# 3  2.9 miles from centre        1 large double bed    Budget Double Room
# 4  3.2 miles from centre              1 double bed   Superior Queen Room
#
#                   Sustainable          Cancellation   City,  Staff  \
# ...
